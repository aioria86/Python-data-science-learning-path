# %%
import pandas as pd

# %%
df_run_times = pd.read_excel('../../data/raw/Run Times.xlsx')

# %%
df_run_times
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
df_run_times.dtypes
# Out:
# Name                       str
# Run Time               float64
# Warm Up Time            object
# Location                   str
# Run Date        datetime64[us]
# Race Date       datetime64[us]
# Rain                      bool
# Fee                        str
# dtype: object

# %%
df_run_times.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          5 non-null      str
#  1   Run Time      5 non-null      float64
#  2   Warm Up Time  5 non-null      object
#  3   Location      5 non-null      str
#  4   Run Date      5 non-null      datetime64[us]
#  5   Race Date     5 non-null      datetime64[us]
#  6   Rain          5 non-null      bool
#  7   Fee           5 non-null      str
# dtypes: bool(1), datetime64[us](2), float64(1), object(1), str(3)
# memory usage: 417.0+ bytes

# %%
df_run_times.head()
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
df_run_times.Fee = pd.to_numeric(df_run_times.Fee.str.replace('$', ''))

# %%
df_run_times.dtypes
# Out:
# Name                       str
# Run Time               float64
# Warm Up Time            object
# Location                   str
# Run Date        datetime64[us]
# Race Date       datetime64[us]
# Rain                      bool
# Fee                    float64
# dtype: object

# %%
pd.to_numeric(df_run_times['Warm Up Time'], errors='coerce')
# Out:
# 0    3.5
# 1    3.5
# 2    NaN
# 3    2.2
# 4    2.0
# Name: Warm Up Time, dtype: float64

# %%
df_run_times['Warm Up Time']
# Out:
# 0      3.5
# 1      3.5
# 2    3 min
# 3      2.2
# 4        2
# Name: Warm Up Time, dtype: object

# %%
df_run_times['Warm Up Time'] = pd.to_numeric(df_run_times['Warm Up Time'].astype('str').str.replace(' min', ''))

# %%
df_run_times.dtypes
# Out:
# Name                       str
# Run Time               float64
# Warm Up Time           float64
# Location                   str
# Run Date        datetime64[us]
# Race Date       datetime64[us]
# Rain                      bool
# Fee                    float64
# dtype: object

# %%
df_run_times.Rain.astype('int')
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Rain, dtype: int64

# %% [markdown]
# #Asignment - Converting Data Types

# %%
df_alarm_survey = pd.read_excel('../../data/raw/Alarm Survey Data.xlsx')

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
df_alarm_survey.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level            str
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating              str
# dtype: object

# %%
df_alarm_survey.number_of_children = df_alarm_survey.number_of_children.astype('int')

# %%
df_alarm_survey.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children      int64
# activity_level            str
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating              str
# dtype: object

# %%
df_alarm_survey.alarm_rating = pd.to_numeric(df_alarm_survey.alarm_rating.str.replace(' stars', ''))

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                   3          active            3.0
# 1          2   31                   3           light            3.0
# 2          3   18                   0  light_activity            4.0
# 3          4   42                   4          active            4.0
# 4          5   30                   1  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df_alarm_survey.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children      int64
# activity_level            str
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %% [markdown]
# ## Cleaning missing data

# %%
df_students = pd.read_excel('../../data/raw/Student Grades.xlsx')

# %%
df_students.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_students.tail()
# Out:
#     Student Class    Year  Grade
# 81      NaN   NaN     NaN    NaN
# 82  Bennett   NaN     NaN    NaN
# 83      NaN   EDA  Junior   84.0
# 84    Gavin   EDA  Senior    NaN
# 85   Calvin   NaN     NaN  100.0

# %%
df_students.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  84 non-null     str
#  1   Class    83 non-null     str
#  2   Year     80 non-null     str
#  3   Grade    82 non-null     float64
# dtypes: float64(1), str(3)
# memory usage: 2.8 KB

# %%
df_students.shape
# Out:
# (86, 4)

# %%
df_students.describe()
# Out:
#             Grade
# count   82.000000
# mean    85.707317
# std     15.527346
# min     45.000000
# 25%     81.000000
# 50%     85.000000
# 75%     90.000000
# max    200.000000

# %%
import numpy as np

# %%
df_students.Year.value_counts()
# Out:
# Year
# Freshman     35
# Sophomore    24
# Junior       20
# Senior        1
# Name: count, dtype: int64

# %%
df_students.Year.value_counts(dropna=False)
# Out:
# Year
# Freshman     35
# Sophomore    24
# Junior       20
# NaN           6
# Senior        1
# Name: count, dtype: int64

# %%
df_students.isna
# Out:
# <bound method DataFrame.isna of     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman   86.0
# 1    Olivia  Freshman Seminar  Freshman   86.0
# 2      Noah  Freshman Seminar  Freshman   86.0
# 3    Sophia  Freshman Seminar  Freshman   87.0
# 4      Liam  Freshman Seminar  Freshman   90.0
# ..      ...               ...       ...    ...
# 81      NaN               NaN       NaN    NaN
# 82  Bennett               NaN       NaN    NaN
# 83      NaN               EDA    Junior   84.0
# 84    Gavin               EDA    Senior    NaN
# 85   Calvin               NaN       NaN  100.0
#
# [86 rows x 4 columns]>

# %%
df_students.isna().sum()
# Out:
# Student    2
# Class      3
# Year       6
# Grade      4
# dtype: int64

# %%
df_students.isna().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# Length: 86, dtype: bool

# %%
df_students[df_students.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %%
df_students[df_students.isna().any(axis=1)].dropna(subset=['Student', 'Class'])
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
df_students.dropna(subset=['Student', 'Class'], inplace=True)

# %%
df_students.shape
# Out:
# (82, 4)

# %%
df_students[df_students.Grade.isna()]
# Out:
#    Student                      Class    Year  Grade
# 62  Landon  Exploratory Data Analysis  Junior    NaN
# 84   Gavin                        EDA  Senior    NaN

# %%
df_students.Grade.mean()
# Out:
# np.float64(85.55)

# %%
df_students.Grade = df_students.Grade.fillna(df_students.Grade.mean())

# %%
df_students.Grade
# Out:
# 0     86.00
# 1     86.00
# 2     86.00
# 3     87.00
# 4     90.00
#       ...
# 77    85.00
# 78    93.00
# 79    91.00
# 80    87.00
# 84    85.55
# Name: Grade, Length: 82, dtype: float64

# %%
df_students[df_students.isna().any(axis=1)]
# Out:
#    Student             Class Year  Grade
# 7    Jacob  Freshman Seminar  NaN   88.0
# 8  William  Freshman Seminar  NaN   89.0
# 9    Ethan  Freshman Seminar  NaN   86.0

# %%
df_students[df_students.Class == 'Freshman Seminar']
# Out:
#      Student             Class      Year  Grade
# 0       Emma  Freshman Seminar  Freshman   86.0
# 1     Olivia  Freshman Seminar  Freshman   86.0
# 2       Noah  Freshman Seminar  Freshman   86.0
# 3     Sophia  Freshman Seminar  Freshman   87.0
# 4       Liam  Freshman Seminar  Freshman   90.0
# 5      Mason  Freshman Seminar  Freshman   90.0
# 6   Isabella  Freshman Seminar  Freshman   90.0
# 7      Jacob  Freshman Seminar       NaN   88.0
# 8    William  Freshman Seminar       NaN   89.0
# 9      Ethan  Freshman Seminar       NaN   86.0
# 10       Ava  Freshman Seminar  Freshman   88.0
# 11   Michael  Freshman Seminar  Freshman   88.0

# %%
df_students.loc[7, 'Year'] = 'Freshman'

# %%
df_students.Year = np.where(df_students.Year.isna(), 'Freshman', df_students.Year)

df_students
# Out:
#     Student             Class      Year  Grade
# 0      Emma  Freshman Seminar  Freshman  86.00
# 1    Olivia  Freshman Seminar  Freshman  86.00
# 2      Noah  Freshman Seminar  Freshman  86.00
# 3    Sophia  Freshman Seminar  Freshman  87.00
# 4      Liam  Freshman Seminar  Freshman  90.00
# ..      ...               ...       ...    ...
# 77    Aaron               EDA    Junior  85.00
# 78  Charles               EDA    Junior  93.00
# 79   Connor               EDA    Junior  91.00
# 80    Riley               EDA    Junior  87.00
# 84    Gavin               EDA    Senior  85.55
#
# [82 rows x 4 columns]

# %% [markdown]
# ## Asignment - Missing Data

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                   3          active            3.0
# 1          2   31                   3           light            3.0
# 2          3   18                   0  light_activity            4.0
# 3          4   42                   4          active            4.0
# 4          5   30                   1  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df_alarm_survey.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   int64
#  3   activity_level      6433 non-null   str
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   int64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 351.9 KB

# %%
df_alarm_survey[df_alarm_survey.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                   2  light_activity            NaN
# 18           19   38                   2  lightly active            NaN
# 23           24   24                   2     very active            NaN
# 26           27   25                   2  lightly active            NaN
# 28           29   29                   2  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                   2     very active            NaN
# 6319       6320   44                   2  lightly active            NaN
# 6375       6309   32                   3           light            NaN
# 6377       6311   30                   2     very active            NaN
# 6386       6320   44                   2  lightly active            NaN
#
#       number_of_snoozes  alarm_rating
# 10                    3             4
# ...

# %%
df_alarm_survey.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: count, dtype: int64

# %%
df_alarm_survey.sleep_quality.fillna(2)
# Out:
# 0       3.0
# 1       3.0
# 2       4.0
# 3       4.0
# 4       1.0
#        ...
# 6428    5.0
# 6429    4.0
# 6430    5.0
# 6431    5.0
# 6432    4.0
# Name: sleep_quality, Length: 6433, dtype: float64

# %%
df_alarm_survey.sleep_quality.value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# NaN     351
# 1.0     103
# Name: count, dtype: int64

# %%
df_alarm_survey.sleep_quality = df_alarm_survey.sleep_quality.fillna(2)

# %% [markdown]
# ## Inconsistent Text & Typos

# %%
df_students.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_students.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# Freshman Seminar             12
# Exploratory Data Analysis    12
# EDA                          12
# Python                        1
# Name: count, dtype: int64

# %%
df_students[df_students.Class.isin(['Exploratory Data Analysis', 'EDA'])]
# Out:
#       Student                      Class       Year   Grade
# 58     Evelyn  Exploratory Data Analysis  Sophomore   89.00
# 59       Jack  Exploratory Data Analysis  Sophomore   84.00
# 60       Ella  Exploratory Data Analysis  Sophomore  200.00
# 61      Chloe  Exploratory Data Analysis  Sophomore   87.00
# 62     Landon  Exploratory Data Analysis     Junior   85.55
# 63  Christian  Exploratory Data Analysis     Junior   77.00
# 64     Jordan  Exploratory Data Analysis     Junior   83.00
# 65   Jonathan  Exploratory Data Analysis     Junior   82.00
# 66       Levi  Exploratory Data Analysis     Junior   91.00
# 67   Victoria  Exploratory Data Analysis     Junior   90.00
# 68     Aubrey  Exploratory Data Analysis     Junior   83.00
# 69      Jaxon  Exploratory Data Analysis     Junior   64.00
# 70     Julian                        EDA     Junior   95.00
# 71      Grace                        EDA     Junior   77.00
# 72     Isaiah                        EDA     Junior   88.00
# ...

# %%
df_students[df_students.Class.isin(['Intro to Python', 'Python'])]
# Out:
#       Student            Class      Year  Grade
# 12  Alexander  Intro to Python  Freshman   85.0
# 13      Logan  Intro to Python  Freshman   85.0
# 14      James  Intro to Python  Freshman   82.0
# 15     Daniel  Intro to Python  Freshman   85.0
# 16     Elijah  Intro to Python  Freshman   85.0
# 17   Benjamin  Intro to Python  Freshman   81.0
# 18        Mia  Intro to Python  Freshman   80.0
# 19        Mia           Python  Freshman   80.0
# 20     Jayden  Intro to Python  Freshman   82.0
# 21      Aiden  Intro to Python  Freshman   86.0
# 22    Matthew  Intro to Python  Freshman   87.0
# 23      Emily  Intro to Python  Freshman   78.0
# 24    Jackson  Intro to Python  Freshman   88.0
# 25      Lucas  Intro to Python  Freshman   77.0
# 26      David  Intro to Python  Freshman   74.0
# 27     Joseph  Intro to Python  Freshman   93.0
# 28    Abigail  Intro to Python  Freshman   89.0
# 29      Avery  Intro to Python  Freshman   79.0
# 30    Anthony  Intro to Python  Freshman   84.0
# ...

# %%
df_students.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_students.Year.value_counts()
# Out:
# Year
# Freshman     38
# Sophomore    24
# Junior       19
# Senior        1
# Name: count, dtype: int64

# %%
df_students.Grade.describe()
# Out:
# count     82.000000
# mean      85.550000
# std       15.443965
# min       45.000000
# 25%       81.000000
# 50%       85.275000
# 75%       89.750000
# max      200.000000
# Name: Grade, dtype: float64

# %%
df_students[df_students.Grade > 100]
# Out:
#    Student                      Class       Year  Grade
# 60    Ella  Exploratory Data Analysis  Sophomore  200.0

# %%
df_students.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# Freshman Seminar             12
# Exploratory Data Analysis    12
# EDA                          12
# Python                        1
# Name: count, dtype: int64

# %%
df_students.Class = np.where(df_students.Class == 'EDA', 'Exploratory Data Analysis', df_students.Class)
df_students.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Exploratory Data Analysis    24
# Intro to SQL                 20
# Freshman Seminar             12
# Python                        1
# Name: count, dtype: int64

# %%
df_students.Class = np.where(df_students.Class == 'Python', 'Intro to Python', df_students.Class)
df_students.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Exploratory Data Analysis    24
# Intro to SQL                 20
# Freshman Seminar             12
# Name: count, dtype: int64

# %%
df_students.Grade = np.where(df_students.Grade > 100, 100, df_students.Grade)
df_students.Grade.describe()
# Out:
# count     82.000000
# mean      84.330488
# std        8.824663
# min       45.000000
# 25%       81.000000
# 50%       85.275000
# 75%       89.750000
# max      100.000000
# Name: Grade, dtype: float64

# %%
df_grades = pd.read_excel('../../data/raw/Student Grades.xlsx')
df_grades.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_grades.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# EDA                          13
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Python                        1
# Name: count, dtype: int64

# %%
class_mappings = {
    'Intro to Python': 'Intro to Python',
    'Intro to SQL': 'Intro to SQL',
    'EDA': 'Exploratory Data Analysis',
    'Freshman Seminar': 'Freshman Seminar',
    'Exploratory Data Analysis': 'Exploratory Data Analysis',
    'Python': 'Intro to Python'
}

# %%
df_grades.Class = df_grades.Class.map(class_mappings)
df_grades.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Exploratory Data Analysis    25
# Intro to SQL                 20
# Freshman Seminar             12
# Name: count, dtype: int64

# %%
df_run_times.head()
# Out:
#      Name  Run Time  Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343           3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842           3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209           3.0  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123           2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342           2.0      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain  Fee
# 0  False  0.0
# 1   True  0.0
# 2  False  2.5
# 3  False  0.0
# 4  False  2.5

# %%
df_run_times.Location = df_run_times.Location.str.lower().str.replace('the ', '').str.strip('“”')

# %%
df_run_times
# Out:
#      Name  Run Time  Warm Up Time Location            Run Date  Race Date  \
# 0  Alexis    9.2343           3.5   school 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842           3.5   school 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209           3.0      gym 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123           2.2   school 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342           2.0      gym 2023-05-10 16:30:00 2023-06-15
#
#     Rain  Fee
# 0  False  0.0
# 1   True  0.0
# 2  False  2.5
# 3  False  0.0
# 4  False  2.5

# %% [markdown]
# ## Asignment - Inconsisten Text & Typos

# %% [markdown]
# df_alarm_survey.head()

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                   3          active            3.0
# 1          2   31                   3           light            3.0
# 2          3   18                   0  light_activity            4.0
# 3          4   42                   4          active            4.0
# 4          5   30                   1  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df_alarm_survey.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6433.000000
# mean   3216.302192    29.069175            1.379761       4.110835
# std    1856.007409     7.472048            1.388768       0.963415
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.000000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000   6433.000000
# mean            1.145811      2.955075
# std             1.599481      1.101363
# min             0.000000      1.000000
# 25%             0.000000      2.000000
# 50%             0.000000      3.000000
# 75%             2.000000      4.000000
# max            19.000000      5.000000

# %%
df_alarm_survey.number_of_children.value_counts()
# Out:
# number_of_children
# 0    2440
# 2    1498
# 1    1172
# 3     788
# 4     331
# 5     204
# Name: count, dtype: int64

# %%
df_alarm_survey.activity_level.value_counts()
# Out:
# activity_level
# active            2450
# lightly active    2289
# light_activity     691
# very active        669
# light              334
# Name: count, dtype: int64

# %%
df_alarm_survey.activity_level = np.where(df_alarm_survey.activity_level.isin(['light_activity', 'light']) , 'lightly active', df_alarm_survey.activity_level)
df_alarm_survey.activity_level.value_counts()
# Out:
# activity_level
# lightly active    3314
# active            2450
# very active        669
# Name: count, dtype: int64

# %% [markdown]
# ## Duplicate Data

# %%
df_students.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_students[df_students.duplicated()]
# Out:
#    Student            Class       Year  Grade
# 19     Mia  Intro to Python   Freshman   80.0
# 43   Isaac     Intro to SQL  Sophomore   96.0
# 44   Isaac     Intro to SQL  Sophomore   96.0

# %%
df_students.drop_duplicates(inplace=True)

# %%
df_students[df_students.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Student, Class, Year, Grade]
# Index: []

# %%
df_students.iloc[40:45, :]
# Out:
#       Student         Class       Year  Grade
# 41  Charlotte  Intro to SQL  Sophomore   92.0
# 42      Isaac  Intro to SQL  Sophomore   96.0
# 45     Harper  Intro to SQL  Sophomore   93.0
# 46       Ryan  Intro to SQL  Sophomore   76.0
# 47      Sofia  Intro to SQL  Sophomore   79.0

# %%
df_students.reset_index(drop=True, inplace=True)

# %%
df_students.iloc[40:45, :]
# Out:
#       Student         Class       Year  Grade
# 40  Charlotte  Intro to SQL  Sophomore   92.0
# 41      Isaac  Intro to SQL  Sophomore   96.0
# 42     Harper  Intro to SQL  Sophomore   93.0
# 43       Ryan  Intro to SQL  Sophomore   76.0
# 44      Sofia  Intro to SQL  Sophomore   79.0

# %% [markdown]
# ## Asignment Duplicate Data

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                   3          active            3.0
# 1          2   31                   3  lightly active            3.0
# 2          3   18                   0  lightly active            4.0
# 3          4   42                   4          active            4.0
# 4          5   30                   1  lightly active            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df_alarm_survey.shape
# Out:
# (6433, 7)

# %%
df_alarm_survey[df_alarm_survey.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 6366       6300   31                   2          active            5.0
# 6367       6301   27                   2  lightly active            4.0
# 6368       6302   41                   3  lightly active            5.0
# 6369       6303   25                   0  lightly active            5.0
# 6370       6304   25                   1  lightly active            5.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                   2          active            5.0
# 6429       6363   31                   1  lightly active            4.0
# 6430       6364   26                   0  lightly active            5.0
# 6431       6365   27                   1          active            5.0
# 6432       6366   18                   0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 6366                  0             3
# ...

# %%
df_alarm_survey[~df_alarm_survey.duplicated()]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                   3          active            3.0
# 1             2   31                   3  lightly active            3.0
# 2             3   18                   0  lightly active            4.0
# 3             4   42                   4          active            4.0
# 4             5   30                   1  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6361       6362   27                   2          active            5.0
# 6362       6363   31                   1  lightly active            4.0
# 6363       6364   26                   0  lightly active            5.0
# 6364       6365   27                   1          active            5.0
# 6365       6366   18                   0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# ...

# %% [markdown]
# ## Outliers

# %%
df_students.hist();

# %%
df_students.Grade.max() - df_students.Grade.min()
# Out:
# np.float64(55.0)

# %%
df_students.hist(bins=55);

# %%
import seaborn as sns

# %%
sns.histplot(df_students);

# %%
sns.histplot(df_students, binwidth=1);

# %%
sns.boxenplot(x=df_students.Grade);

# %%
q25, q50 , q75 = np.percentile(df_students.Grade,(25, 50, 75))

# %%
iqr = q75 - q25

# %%
min_grade = q25 - 1.5*iqr
max_grade = q75 + 1.5+iqr

# %%
min_grade, q25, q50, q75, max_grade
# Out:
# (np.float64(69.0),
#  np.float64(81.0),
#  np.float64(85.0),
#  np.float64(89.0),
#  np.float64(98.5))

# %%
df_students[df_students.Grade < 69]
# Out:
#    Student                      Class       Year  Grade
# 36    John            Intro to Python   Freshman   50.0
# 53   Wyatt               Intro to SQL  Sophomore   45.0
# 66   Jaxon  Exploratory Data Analysis     Junior   64.0

# %%
mean = np.mean(df_students.Grade)
sd = np.std(df_students.Grade)

# %%
mean, sd
# Out:
# (np.float64(84.08987341772152), np.float64(8.723725033779411))

# %%
[grade for grade in df_students.Grade if (grade < mean-3*sd) or (grade > mean + 3*sd)]
# Out:
# [50.0, 45.0]

# %%
df_students.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_students.shape
# Out:
# (79, 4)

# %%
df_students[df_students.Grade < 60]
# Out:
#    Student            Class       Year  Grade
# 36    John  Intro to Python   Freshman   50.0
# 53   Wyatt     Intro to SQL  Sophomore   45.0

# %%
df_students.drop([36, 53])
# Out:
#     Student                      Class      Year  Grade
# 0      Emma           Freshman Seminar  Freshman  86.00
# 1    Olivia           Freshman Seminar  Freshman  86.00
# 2      Noah           Freshman Seminar  Freshman  86.00
# 3    Sophia           Freshman Seminar  Freshman  87.00
# 4      Liam           Freshman Seminar  Freshman  90.00
# ..      ...                        ...       ...    ...
# 74    Aaron  Exploratory Data Analysis    Junior  85.00
# 75  Charles  Exploratory Data Analysis    Junior  93.00
# 76   Connor  Exploratory Data Analysis    Junior  91.00
# 77    Riley  Exploratory Data Analysis    Junior  87.00
# 78    Gavin  Exploratory Data Analysis    Senior  85.55
#
# [77 rows x 4 columns]

# %%
df_students[df_students.Grade > 60]
# Out:
#     Student                      Class      Year  Grade
# 0      Emma           Freshman Seminar  Freshman  86.00
# 1    Olivia           Freshman Seminar  Freshman  86.00
# 2      Noah           Freshman Seminar  Freshman  86.00
# 3    Sophia           Freshman Seminar  Freshman  87.00
# 4      Liam           Freshman Seminar  Freshman  90.00
# ..      ...                        ...       ...    ...
# 74    Aaron  Exploratory Data Analysis    Junior  85.00
# 75  Charles  Exploratory Data Analysis    Junior  93.00
# 76   Connor  Exploratory Data Analysis    Junior  91.00
# 77    Riley  Exploratory Data Analysis    Junior  87.00
# 78    Gavin  Exploratory Data Analysis    Senior  85.55
#
# [77 rows x 4 columns]

# %%
df_students[df_students.Grade < 60]
# Out:
#    Student            Class       Year  Grade
# 36    John  Intro to Python   Freshman   50.0
# 53   Wyatt     Intro to SQL  Sophomore   45.0

# %%
min_grade = df_students[df_students.Grade > 60].Grade.min()
min_grade
# Out:
# np.float64(64.0)

# %%
df_students.Grade = np.where(df_students.Grade < 60, min_grade, df_students.Grade)
df_students.Grade.describe()
# Out:
# count     79.000000
# mean      84.507595
# std        7.263758
# min       64.000000
# 25%       81.000000
# 50%       85.000000
# 75%       89.000000
# max      100.000000
# Name: Grade, dtype: float64

# %%
df_students[df_students.Student == 'John']
# Out:
#    Student            Class      Year  Grade
# 36    John  Intro to Python  Freshman   74.0

# %%
df_students.loc[36, 'Grade'] = 74

# %% [markdown]
# ## Asignment Outliers

# %%
df_alarm_survey.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                   3          active            3.0
# 1          2   31                   3  lightly active            3.0
# 2          3   18                   0  lightly active            4.0
# 3          4   42                   4          active            4.0
# 4          5   30                   1  lightly active            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df_alarm_survey.hist(figsize=(6,8));

# %%
sns.histplot(df_alarm_survey.number_of_snoozes);

# %%
sns.boxplot(x= df_alarm_survey.number_of_snoozes);

# %%
    df_alarm_survey.number_of_snoozes.value_counts()
# Out:
# number_of_snoozes
# 0     3367
# 1     1229
# 2      693
# 4      427
# 5      345
# 3      309
# 6       59
# 8        2
# 19       1
# 7        1
# Name: count, dtype: int64

# %%
df_alarm_survey[df_alarm_survey.number_of_snoozes >= 19]
# Out:
#      survey_id  age  number_of_children  activity_level  sleep_quality  \
# 749        750   19                   1  lightly active            5.0
#
#      number_of_snoozes  alarm_rating
# 749                 19             3

# %%
df_alarm_survey = df_alarm_survey[df_alarm_survey.number_of_snoozes < 19]
df_alarm_survey
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                   3          active            3.0
# 1             2   31                   3  lightly active            3.0
# 2             3   18                   0  lightly active            4.0
# 3             4   42                   4          active            4.0
# 4             5   30                   1  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                   2          active            5.0
# 6429       6363   31                   1  lightly active            4.0
# 6430       6364   26                   0  lightly active            5.0
# 6431       6365   27                   1          active            5.0
# 6432       6366   18                   0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# ...
